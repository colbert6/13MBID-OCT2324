# %% [markdown]
# ## Máster en Big Data y Data Science
#
# ### Metodologías de gestión y diseño de proyectos de big data
#
# #### AP1 - Exploración de los datos
#
# ---
#
# En esta libreta se realiza un EDA -básico- de los datos del escenario.
#
# ---

# %% [markdown]
# ##### Importación de librerías

# %%
import pandas as pd
# from ydata_profiling import ProfileReport
import dtale as dt
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ----
#
# ##### Lectura de los datasets

# %%
df_creditos = pd.read_csv("../../data/raw/datos_creditos.csv", sep=";")
df_creditos.head(1)
# Out:
#     id_cliente  edad  importe_solicitado  duracion_credito  \
# 0  713061558.0    22               35000                 3
#
#    antiguedad_empleado situacion_vivienda  ingresos objetivo_credito  \
# 0                123.0           ALQUILER     59000         PERSONAL
#
#    pct_ingreso  tasa_interes  estado_credito falta_pago
# 0         0.59         16.02               1          Y

# %%
df_tarjetas = pd.read_csv("../../data/raw/datos_tarjetas.csv", sep=";")
df_tarjetas.head(1)
# Out:
#     id_cliente  antiguedad_cliente estado_civil estado_cliente  \
# 0  713061558.0                36.0       CASADO         ACTIVO
#
#    gastos_ult_12m genero  limite_credito_tc         nivel_educativo  \
# 0          1088.0      M             4010.0  UNIVERSITARIO_COMPLETO
#
#   nivel_tarjeta  operaciones_ult_12m  personas_a_cargo
# 0          Blue                 24.0               2.0

# %% [markdown]
# ----
#
# ##### Descripción de los datasets

# %%
def reporte_descripcion_dataset(df):
    columnas = df.columns
    print("Columnas del dataset:\n")
    for col in columnas:
        print(col)
    print(f"\nCantidad de filas: {df.shape[0]}")

# %%
print("Descripción del dataset 'datos_creditos'")
reporte_descripcion_dataset(df_creditos)
# Out:
# Descripción del dataset 'datos_creditos'
# Columnas del dataset:
#
# id_cliente
# edad
# importe_solicitado
# duracion_credito
# antiguedad_empleado
# situacion_vivienda
# ingresos
# objetivo_credito
# pct_ingreso
# tasa_interes
# estado_credito
# falta_pago
#
# Cantidad de filas: 10127

# %%
print("Descripción del dataset 'datos_tarjetas'")
reporte_descripcion_dataset(df_tarjetas)
# Out:
# Descripción del dataset 'datos_tarjetas'
# Columnas del dataset:
#
# id_cliente
# antiguedad_cliente
# estado_civil
# estado_cliente
# gastos_ult_12m
# genero
# limite_credito_tc
# nivel_educativo
# nivel_tarjeta
# operaciones_ult_12m
# personas_a_cargo
#
# Cantidad de filas: 10127

# %% [markdown]
# ----
#
# ##### Obtención de metadatos

# %%
# Se usa la librería dtale para poder obtener una vista interactiva de los datos

# Dataset: datos_creditos

creditos = dt.show(df_creditos)
creditos.open_browser()
# Out:
# 2024-04-17 19:18:18,827 - ERROR    - Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\colbe\Documents\VIU\MetologíaProyectos\13MBID-OCT2324\.venv\lib\site-packages\flask\app.py", line 2529, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\colbe\Documents\VIU\MetologíaProyectos\13MBID-OCT2324\.venv\lib\site-packages\flask\app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\colbe\Documents\VIU\MetologíaProyectos\13MBID-OCT2324\.venv\lib\site-packages\flask\app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\colbe\Documents\VIU\MetologíaProyectos\13MBID-OCT2324\.venv\lib\site-packages\flask\app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "c:\Users\colbe\Documents\VIU\MetologíaProyectos\13MBID-OCT2324\.venv\lib\site-packages\dash\dash.py", line 1352, in dispatch
#     ctx.run(
#   File "c:\Users\colbe\Documents\VIU\MetologíaProyectos\13MBID-OCT2324\.venv\lib\site-packages\dash\_callback.py", line 450, in add_context
#     output_value = _invoke_callback(func, *func_args, **func_kwargs)
#   File "c:\Users\colbe\Documents\VIU\MetologíaProyectos\13MBID-OCT2324\.venv\lib\site-packages\dash\_callback.py", line 39, in _invoke_callback
#     return func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\Users\colbe\Documents\VIU\MetologíaProyectos\13MBID-OCT2324\.venv\lib\site-packages\dtale\dash_application\views.py", line 1338, in group_values
#     group_types = get_group_types(inputs, group_cols)
#   File "c:\Users\colbe\Documents\VIU\MetologíaProyectos\13MBID-OCT2324\.venv\lib\site-packages\dtale\dash_application\layout\layout.py", line 698, in get_group_types
#     return _flags("pareto_group")
#   File "c:\Users\colbe\Documents\VIU\MetologíaProyectos\13MBID-OCT2324\.venv\lib\site-packages\dtale\dash_application\layout\layout.py", line 667, in _flags
#     col, freq = fgc.split(CHART_JOINER_CHAR)
# ValueError: not enough values to unpack (expected 2, got 1)
# 2024-04-17 20:21:38,137 - INFO     - Executing shutdown due to inactivity...
# 2024-04-17 20:21:50,701 - INFO     - Executing shutdown...
# 2024-04-17 20:21:50,706 - INFO     - Not running with the Werkzeug Server, exiting by searching gc for BaseWSGIServer

# %%
# Dataset: datos_tarjetas

tarjetas = dt.show(df_tarjetas)
tarjetas.open_browser()

# %% [markdown]
# ----
#
# ##### Gráficos de interés

# %%
plt.figure(figsize=(7,5))
sns.countplot(y=df_creditos['objetivo_credito'], order=df_creditos['objetivo_credito'].value_counts().index)
plt.show()

# %%
numeric_df = df_creditos.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_df.corr()
# Crear el mapa de calor
plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Matriz de Correlación')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df_creditos['pct_ingreso'], df_creditos['importe_solicitado'])
plt.title('Correlación entre pct_ingreso e importe_solicitado')
plt.xlabel('pct_ingreso')
plt.ylabel('importe_solicitado')
plt.grid(True)
plt.show()
